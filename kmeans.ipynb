# %%
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd

# %%
df=pd.read_csv("plotting.csv")
df
# Out:
#      Rank                                   Name         City Code  \
# 0       1                     Harvard University    Cambridge   MA
# 1       2                    Stanford University     Stanford   CA
# 2       3                        Yale University    New Haven   CT
# 3       4  Massachusetts Institute of Technology    Cambridge   MA
# 4       5                   Princeton University    Princeton   NJ
# ..    ...                                    ...          ...  ...
# 645   646            New Mexico State University   Las Cruces   NM
# 646   647               Indiana State University  Terre Haute   IN
# 647   648              Emory &amp; Henry College        Emory   VA
# 648   649                          Wells College       Aurora   NY
# 649   650                        Catawba College    Salisbury   NC
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0          Private                     13844               31120    14327.0
# ...

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this
df["SAT mean"]=(df["SAT Lower"]+df["SAT Upper"])/2

X = df["SAT mean"].values.reshape(-1, 1)
y = df["Acceptance Rate"].values.reshape(-1, 1)

print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (650, 1) (650, 1)

# %%
col_data=df.dropna()

# %%
col_data
# Out:
#      Rank                                   Name         City Code  \
# 0       1                     Harvard University    Cambridge   MA
# 1       2                    Stanford University     Stanford   CA
# 2       3                        Yale University    New Haven   CT
# 3       4  Massachusetts Institute of Technology    Cambridge   MA
# 4       5                   Princeton University    Princeton   NJ
# ..    ...                                    ...          ...  ...
# 644   645                      Morehouse College      Atlanta   GA
# 645   646            New Mexico State University   Las Cruces   NM
# 646   647               Indiana State University  Terre Haute   IN
# 647   648              Emory &amp; Henry College        Emory   VA
# 649   650                        Catawba College    Salisbury   NC
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0          Private                     13844               31120    14327.0
# ...

# %%
col_data.count()
# Out:
# Rank                        523
# Name                        523
# City                        523
# Code                        523
# Public/Private              523
# Undergraduate Population    523
# Student Population          523
# Net Price                   523
# Average Grant Aid           523
# Total Annual Cost           523
# Alumni Salary               523
# Acceptance Rate             523
# SAT Lower                   523
# SAT Upper                   523
# ACT Lower                   523
# ACT Upper                   523
# Website                     523
# lat                         523
# lon                         523
# State                       523
# SAT mean                    523
# dtype: int64

# %%
col_data.reset_index(inplace=True)

# %%
col_data.drop(["index"],axis=1)
# Out:
#      Rank                                   Name         City Code  \
# 0       1                     Harvard University    Cambridge   MA
# 1       2                    Stanford University     Stanford   CA
# 2       3                        Yale University    New Haven   CT
# 3       4  Massachusetts Institute of Technology    Cambridge   MA
# 4       5                   Princeton University    Princeton   NJ
# ..    ...                                    ...          ...  ...
# 518   645                      Morehouse College      Atlanta   GA
# 519   646            New Mexico State University   Las Cruces   NM
# 520   647               Indiana State University  Terre Haute   IN
# 521   648              Emory &amp; Henry College        Emory   VA
# 522   650                        Catawba College    Salisbury   NC
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0          Private                     13844               31120    14327.0
# ...

# %% [markdown]
# # SAT Mean vs Acceptance Rate

# %%
# reading values into new_x
X=[]
for i in range(523):
    X.append([col_data["SAT mean"][i],col_data["Acceptance Rate"][i]])

# %%
len(X)
# Out:
# 523

# %%
#elbow method to find the number of clusters
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
    kmeans1=KMeans(n_clusters=i, init='k-means++',random_state=0)
    kmeans1.fit(X)
    wcss.append(kmeans1.inertia_)
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#Fitting K-MEans to the dataset
kmeans1=KMeans(n_clusters=5,init='k-means++',random_state=0)
y_kmeans1=kmeans1.fit_predict(X)

# %%
y_kmeans1
# Out:
# array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 1, 3, 3, 3, 1, 3, 3, 3, 3, 3,
#        1, 3, 3, 1, 3, 3, 1, 3, 1, 1, 1, 1, 2, 1, 3, 1, 1, 1, 1, 1, 3, 3,
#        1, 1, 1, 3, 3, 1, 1, 1, 3, 2, 2, 2, 1, 1, 1, 1, 1, 1, 1, 1, 3, 1,
#        1, 2, 3, 3, 1, 2, 1, 1, 3, 2, 3, 1, 1, 2, 2, 1, 1, 2, 2, 2, 1, 1,
#        1, 2, 2, 2, 1, 4, 1, 1, 2, 1, 2, 1, 1, 1, 2, 2, 2, 1, 2, 3, 1, 2,
#        2, 1, 1, 2, 2, 1, 2, 1, 2, 2, 2, 2, 4, 2, 2, 2, 1, 2, 1, 2, 2, 2,
#        3, 2, 1, 1, 2, 2, 2, 2, 4, 2, 1, 4, 4, 1, 2, 2, 4, 2, 1, 4, 2, 2,
#        1, 1, 2, 1, 4, 4, 2, 2, 2, 4, 4, 1, 2, 2, 4, 2, 2, 4, 4, 1, 1, 2,
#        2, 2, 2, 2, 1, 2, 2, 4, 2, 2, 2, 2, 4, 4, 4, 0, 4, 2, 4, 4, 4, 2,
#        2, 2, 2, 2, 1, 4, 2, 4, 4, 4, 2, 1, 2, 2, 4, 4, 0, 4, 4, 4, 2, 2,
#        4, 2, 4, 2, 4, 4, 4, 2, 4, 4, 2, 2, 4, 4, 2, 2, 4, 2, 2, 2, 2, 2,
#        4, 4, 1, 4, 4, 4, 2, 4, 4, 2, 0, 4, 4, 0, 2, 1, 2, 4, 4, 4, 4, 4,
# ...

# %%
#visualize the clusters(sat mean vs acceptance rate)
color=["green","red","blue","grey","cyan"]
for i in range(0,5):
    cluster = [d for b, d in zip(y_kmeans1 == i, X) if b == True]
    cluster = pd.DataFrame(cluster)
    plt.scatter(cluster[0], cluster[1],s=100,c=color[i],label=f"Cluster{i}")
plt.scatter(kmeans1.cluster_centers_[:,0],kmeans1.cluster_centers_[:,1
             ],s=300,c='yellow',label='Centroids')
plt.title('')
plt.xlabel('SAT MEAN')
plt.ylabel('ACCEPTANCE RATE')
plt.legend()
plt.show()

# %%
kmeans1.predict([[1350,100]])
# Out:
# array([2])

# %% [markdown]
# # SAT Mean vs Alumni Salary

# %%
X1=[]
for i in range(523):
    X1.append([col_data["Alumni Salary"][i],col_data["SAT mean"][i]])

# %%
#elbow method to find the number of clusters
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
    kmeans2=KMeans(n_clusters=i, init='k-means++',random_state=0)
    kmeans2.fit(X1)
    wcss.append(kmeans2.inertia_)
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#Fitting K-MEans to the dataset
kmeans2=KMeans(n_clusters=5,init='k-means++',random_state=0)
y_kmeans2=kmeans2.fit_predict(X1)

# %%
#visualize the clusters(sat mean vs alumni salary)
color=["green","red","blue","grey","cyan"]
for i in range(0,5):
    cluster = [d for b, d in zip(y_kmeans2 == i, X1) if b == True]
    cluster = pd.DataFrame(cluster)
    plt.scatter(cluster[0], cluster[1],s=100,c=color[i],label=f"Cluster{i}")
plt.scatter(kmeans2.cluster_centers_[:,0],kmeans2.cluster_centers_[:,1
             ],s=300,c='yellow',label='Centroids')
plt.title('')
plt.ylabel('SAT MEAN')
plt.xlabel('Alumni Salary')
plt.legend()
plt.figure(figsize=(20,20))
plt.show()

# %%
kmeans2.predict([[120000,1500],[1250,40]])
# Out:
# array([0, 2])

# %% [markdown]
# # Acceptance Rate vs Alumni Salary

# %%
X2=[]
for i in range(523):
    X2.append([col_data["Acceptance Rate"][i],col_data["Alumni Salary"][i]])

# %%
#elbow method to find the number of clusters
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
    kmeans3=KMeans(n_clusters=i, init='k-means++',random_state=0)
    kmeans3.fit(X2)
    wcss.append(kmeans3.inertia_)
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#Fitting K-MEans to the dataset
kmeans3=KMeans(n_clusters=5,init='k-means++',random_state=0)
y_kmeans3=kmeans3.fit_predict(X2)

# %%
#visualize the clusters(sat mean vs alumni salary)
color=["green","red","blue","grey","cyan"]
for i in range(0,5):
    cluster = [d for b, d in zip(y_kmeans3 == i, X2) if b == True]
    cluster = pd.DataFrame(cluster)
    plt.scatter(cluster[0], cluster[1],s=100,c=color[i],label=f"Cluster{i}")
plt.scatter(kmeans3.cluster_centers_[:,0],kmeans3.cluster_centers_[:,1
             ],s=300,c='yellow',label='Centroids')
plt.title('')
plt.xlabel('Acceptance Rate')
plt.ylabel('Alumni Salary')
plt.legend()
plt.show()
